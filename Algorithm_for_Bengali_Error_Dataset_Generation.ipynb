# %% [markdown]
# <a href="https://colab.research.google.com/github/habibsifat/Algorithm-for-Bengali-Error-Dataset-Generation/blob/master/Algorithm_for_Bengali_Error_Dataset_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Data Load***

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/Capstone/Data'
corpus_file = '/content/drive/My Drive/Colab Notebooks/Capstone/Data/words.txt'

# %%
sentences = []
with open(corpus_file, 'r', encoding="utf-8-sig") as f:
    for line in f:
        sentences.append(line.split())       
print('Num sentences:', len(sentences))

# %% [markdown]
# # **Phonetic Similar Cluster Replacement**

# %%
from random import random, choice
SameClusterDict = {
    'ঋ' : ['রি'],
    'ঐ': ['অই'],
    'ঔ': ['অউ'],
    'খ': ['ক'],
    'ঙ': ['◌ং'],
    'ঝ': ['জ'],
    'ঠ' : ['ট','ত'],
    'ড' : ['দ'],
    'ঢ': ['ড'],
    'থ': ['ত','ট'],
    'দ' : ['ড'],
    'ধ' : ['দ','ড'],
    'ভ' : ['ব'],
    'য' : ['জ'],
    'ৎ' : ['ত'],
    'ং' : ['ঙ'],
    'ঃ': ['হ'],
    '‍ঁ' : [''],
    'ৈ'  :['ই'],
    'ৌ':['উ'],
    '‍ঢ়': ['র'],
    'ড়' : ['র'],
    'ৃ' : ['রি'],
    'অ' : ['ও'],
    'ই':['ঈ'],
    'উ' : ['ঊ'],
    'চ': ['ছ'],
    'ট' :['ত'],
    'ড': ['দ'],
    'ন': ['ণ'],
     'য' : ['জ'],
     'শ' : ['স','ষ'],
     'ি' : ['◌ী'],
     'ু' : ['◌ূ']
}

def SameClusterFun(c):
  if c in SameClusterDict:
    c2 = choice(SameClusterDict[c])
    print(c2,end='')
    f.write(c2)
  else:
    print(c,end='')
    f.write(c)

# %% [markdown]
# # **Single Letter Miss-pressed Cluster Replacement**

# %%
from random import random, choice
ReplaceDict = {
               'ক' : ['ল','য'],
               'খ' : ['কগ','কজ','লহ','ঝ'],
               'গ' : ['ফ','হ'],
               'ঘ' : ['ফগ','হজ'],
               'ঙ' : ['ব','ম'],
               'চ' : ['ভ','চজ','চগ','ভহ'],
               'ছ' : ['ভ','চজ','চগ','ভহ'],
               'জ' : ['ক','হ'],
               'ঝ' : ['কজ','হগ'],
               'ট' : ['র'],
               'ঠ' : ['তজ','তগ','রহ'],
               'ড' : ['স','ফ'],
               'ঢ' : ['দজ','দ্গ','শ','ফহ'],
               'ণ' : ['ব','ম'],
               'ত' : ['র'],
              'থ' : ['তজ', 'তগ', 'রহ'],
              'দ' : ['স', 'ফ'],
              'ধ' : ['দজ', 'দ্গ', 'শ' ,'ফহ'],
              'ন' : ['ব','ম'],
              'প' : ['ও',' ো'],
              'ফ' : ['দ','গ'],
              'ব' : ['ভ','ন'],
              'ভ' : ['‍ব','চ'],
              'ম' : ['ন'],
              'য' : ['হ','ক'],
              'র' : ['এ',' ে','ত'],
              'ল' : ['ক'],
              'শ' : ['সজ','সগ','আহ','ঢ'],
              'ষ' : ['সজ','সগ','আহ','ঢ'],
              'স' : ['আ',' া','দ'],
              'হ' : ['গ','য'],
              'য়' : ['ত','উ','ু'],
              'ড়' : ['এ',' ে','ত'],
              'ঢ়' : ['এ',' ে','ত'],
              'ৎ' : ['র'],
              'ং' : ['ব','ম'],
              'ঃ' : ['গ','য'],
              'অ' : ['প',' ি','ই'],
              'আ' : ['স'],
              'ই' : ['উ','অ'],
              'ঈ' : ['উ','অ'],
              'উ' : ['ই',' ি'],
              'ঊ' : ['ই',' ি'],
              'ঋ' : [''],
              'এ' : ['ও','র'],
              'ঐ' : [''],
              'ও' : ['প','ই'],
              'ঔ' : [''],
              'া' : ['স'],
              'ি' : ['উ','অ'],
              'ো' : ['প',' ি'],
              'ৌ' : [''],
              'ে' : ['ো','র'],
              'ৈ' : ['']
              }

def ReplacementFun(c):
  if c in ReplaceDict:
    c2 = choice(ReplaceDict[c])
    print(c2,end='')
    f.write(c2)
  else:
    print(c,end='')
    f.write(c)

# %% [markdown]
# # ***Main Function***

# %% [markdown]
# **Jukto Borno**

# %%
JBList = [' ক্ট ' , ' ক্ক ' , ' ক্ত ' , ' ক্য ' , ' ক্র ' , ' ক্ল ' , ' ক্ষ ' , ' ক্ষ্ণ ' , ' ক্ষ্ম ' , ' ক্ষ্য ' , ' ক্স ' , ' খ্র ' , ' গ্ধ ' , ' গ্ধ্য ' , ' গ্ন ' , ' গ্ন্য ' , ' গ্ব ' , ' গ্র ' , ' গ্র্য ' , ' গ্ল ' , ' ঘ্ন ' , ' ঘ্র ' , ' ঙ্ক্য ' , ' ঙ্গ্য ' , ' চ্চ ' , ' চ্ছ্ব ' , ' চ্য ' , ' জ্জ ' , ' জ্জ্ব ' , ' ট্ট ' , ' জ্ব ' , ' জ্য ' , ' জ্র ' , ' ট্য ' , ' ট্র ' , ' ড্ড ' , ' ড্র ' , ' ণ্ট ' , ' ণ্ঠ ' , ' ণ্ড ' , ' ণ্ণ ' , ' ণ্য ' , ' ৎক ' , ' ৎখ ' , ' ত্ত ' , ' ত্ত্ব ' , ' ত্ত্য ' , ' ত্ন ' , ' ৎপ ' , ' ত্ব ' , ' ত্ম ' , ' ত্ম্য ' , ' ত্য ' , ' ত্র ' , ' ত্র্য ' , ' ৎস ' , ' দ্ঘ ' , ' দ্দ ' , ' দ্ধ ' , ' দ্ব ' , ' দ্ভ ' , ' দ্ভ্র ' , ' দ্ম ' , ' দ্য ' , ' দ্র ' , ' দ্র্য ' , ' ধ্ব ' , ' ধ্য ' , ' ধ্র ' , ' ন্ট ' , ' ন্ট্র ' , ' ন্ঠ ' , ' ন্ড ' , ' ন্ড্র ' , ' ন্ত ' , ' ন্ত্ব ' , ' ন্ত্য ' , ' ন্ত্র ' , ' ন্ত্র্য ' , ' ন্থ ' , ' ন্দ ' , ' ন্দ্ব ' , ' ন্দ্র ' , ' ন্ধ ' , ' ন্ন ' , ' ন্য ' , ' প্ট ' , ' প্ত ' , ' প্ন ' , ' প্প ' , ' প্য ' , ' ব্দ ' , ' ব্ধ ' , ' ব্ব ' , ' ব্র ' , ' ভ্য ' , ' ভ্র ' , ' ম্প্র ' , ' ম্ব ' , ' ম্ম ' , ' ম্য ' , ' ম্র ' , ' য্য ' , ' র্ক ' , ' র্গ্য ' , ' র্ঘ্য ' , ' র্জ্য ' , ' র্থ্য ' , ' র্ব্য ' , ' র্খ ' , ' র্গ ' , ' র্ঘ ' , ' র্চ ' , ' র্ছ ' , ' র্জ ' , ' র্ঝ ' , ' র্ট ' , ' র্ড ' , ' র্ণ ' , ' র্ত ' , ' র্থ ' , ' র্দ ' , ' র্দ্ব ' , ' র্দ্র ' , ' র্ধ ' , ' র্ধ্ব ' , ' ল্ট ' , ' ল্ড ' , ' ল্প ' , ' ল্ম ' , ' ল্য ' , ' ল্ল ' , ' শ্ছ ' , ' শ্ন ' , ' শ্ব ' , ' শ্র ' , ' শ্ল ' , ' ষ্ক ' , ' ষ্ক্র ' , ' ষ্ট ' , ' ষ্ট্য ' , ' ষ্ট্র ' , ' ষ্ঠ ' , ' ষ্প ' , ' স্ট ' , ' স্ট্র ' , ' স্ত্র ' , ' স্ত ' , ' স্থ্য ' , ' স্য ' , ' স্র ' , ' স্ল ' , ' হ্র ' , ' হ্ল ' , ' গ্ম ' , ' ম্ভ ' , ' স্ম ' , ' ঙ্ঘ ' , ' ঙ্ক্ষ ' , ' ঙ্খ ' , ' ঙ্ক ' , ' ঙ্‌ক্ত ' , ' ঞ্চ ' , ' ঞ্ছ ' , ' ঞ্জ ' , ' হ্ন ' , ' ঙ্গ ' , ' জ্ঞ ' , ' গ্য ' , ' চ্ছ ' , ]
print(len(JBList))
def JuktoBorno(word,pos):  
  if word[pos] == 'জ' and word[pos+2] == 'ঞ':
    if pos == 0:
      print("গ",end='')
      f.write("গ")
    else:
      print("জ্ঞ",end='')
      f.write("জ্ঞ")
  elif word[pos] == 'গ' and word[pos+2] == 'য':
    if pos == 0:
      print("গা",end='')
      f.write("গা")
    else:
      print("জ্ঞ",end='')
      f.write("জ্ঞ")
  elif word[pos] == 'চ' and word[pos+2] == 'ছ':
    r = random()
    if r < .5:
      print("ছছ",end='')
      f.write("ছছ")
    else:
      print("ছ",end='')
      f.write("ছ")
  elif word[pos+2] == 'য':
    if pos+2 == len(word):
      print(word[pos],end='')
      f.write(word[pos])
      print(word[pos],end='')
      f.write(word[pos])
    else:
      r = random()
      if r < .5:
        print(word[pos],end='')
        f.write(word[pos])
        print("া",end='')
        f.write("া")
      else:
        print("ে",end='')
        f.write("ে")
        print(word[pos],end='')
        f.write(word[pos])
  elif word[pos] == 'স' and word[pos+2] == 'ম':
    SameClusterFun(word[pos])
  elif word[pos] == 'দ' and word[pos+2] == 'ম':
    SameClusterFun(word[pos])
    f.write("ং")
    SameClusterFun(word[pos])
  elif word[pos] == 'ম':
    SameClusterFun(word[pos+2])
  elif word[pos+2] == 'ম':
    SameClusterFun(word[pos])
  elif word[pos] == 'ব':
    print(word[pos+2],end='')
    f.write(word[pos+2])
  elif word[pos+2] == 'ব':
    print(word[pos],end='')
    f.write(word[pos])
  elif word[pos] == 'র':
    print(word[pos],end='')
    f.write(word[pos])
    f.write("ং")
    SameClusterFun(word[pos+2])
  elif word[pos+2] == 'র':
    SameClusterFun(word[pos])
    f.write("ং")
    print(word[pos+2],end='')
    f.write(word[pos+2])
  elif word[pos] == 'ক' and word[pos+2] == 'ষ':
    if pos == 0:
      print("খ",end='')
      f.write("খ")
    else:
      print("ক্ক",end='')
      f.write("ক্ক")
  elif word[pos+2] == 'ঙ':
    if word[pos+3] == "া" :
      SameClusterFun(word[pos])
      print("ঙ্গা",end='')
      f.write("ঙ্গা")
    else:
      SameClusterFun(word[pos])
      print("ং",end='')
      f.write("গ")
  elif word[pos] == 'ঙ':
    print("ং",end='')
    f.write("ং")
    SameClusterFun(word[pos+2])
  elif word[pos] == 'ঞ':
    print("ঞ",end='')
    f.write("ঞ")
    SameClusterFun(word[pos+2])
  elif word[pos] == 'হ' and word[pos+2] == 'ন':
    print("ন্ন",end='')
    f.write("ন্ন")
  elif word[pos] == 'ন' and word[pos+2] == 'ন':
    print("হ্ন",end='')
    f.write("হ্ন")
  elif word[pos] == word[pos+2]:
    SameClusterFun(word[pos+2])
    f.write("্")
    SameClusterFun(word[pos+2])
  elif word[pos] == 'ল' or word[pos] == 'ত' or word[pos] == 'থ' or word[pos] == 'দ' or word[pos] == 'ধ' or word[pos] == 'ট' or word[pos] == 'ঠ' or word[pos] == 'স' or word[pos] == ' শ' or  word[pos] == 'ষ':
    print(word[pos],end='')
    f.write(word[pos])
    f.write("্")
    SameClusterFun(word[pos+2])
  elif word[pos+2] == 'ল' or word[pos+2] == 'ত' or word[pos+2] == 'থ' or word[pos+2] == 'দ' or word[pos+2] == 'ধ' or word[pos+2] == 'ট' or word[pos+2] == 'ঠ' or word[pos+2] == 'স' or word[pos+2] == ' শ' or  word[pos+2] == 'ষ':
    SameClusterFun(word[pos])
    f.write("্")
    print(word[pos+2],end='')
    f.write(word[pos+2])
  elif word[pos] == 'ন' or word[pos] == 'ণ':
    SameClusterFun(word[pos])
    f.write("্")
    SameClusterFun(word[pos+2])
  elif word[pos+2] == 'ন' or word[pos+2] == 'ণ':
    SameClusterFun(word[pos])
    f.write("্")
    SameClusterFun(word[pos+2])
  else:
    print(word[pos],end='')
    f.write(word[pos])
    print(word[pos+1],end='')
    f.write(word[pos+1])
    print(word[pos+2],end='')
    f.write(word[pos+2])

# %%
from random import *
f = open("Error1.txt", "x")
f = open("Error1.txt", "a")
for line in sentences:
  for word in line:
    print(word,end=' , ')
    #f.write(word)
    #f.write(",")
    pos=0
    flag1=0
    flag2=0
    flag3=0
    while(pos<len(word)):
      if flag1 == 1 and flag2 == 1 or flag3 == 1:
        print(word[pos],end='')
        f.write(word[pos])
        pos += 1
      else:
        if(pos+1<len(word) and word[pos+1] == '্'):
          r = random()
          if r <= .70 and flag1 == 1:
            print(word[pos],end='')
            f.write(word[pos])
            print(word[pos+1],end='')
            f.write(word[pos+1])
            print(word[pos+2],end='')
            f.write(word[pos+2])
            pos=pos+3
          else:
            flag1=1
            JuktoBorno(word,pos)
            pos=pos+3
        else:
          r = random()
          # Same Cluster
          if r <=.2:
            flag2=1
            SameClusterFun(word[pos])
          #Replacement
          elif r>.5 and r<=.7:
            if flag3 == 1:
              print(word[pos],end='')
              f.write(word[pos])
            else:
              flag3=1
              ReplacementFun(word[pos])
          else:
            print(word[pos],end='')
            f.write(word[pos])
          pos+=1
  print()
  f.write("\n")
f.close()

# %% [markdown]
# # **Single letter miss-pressed cluster insertion**

# %%
corpus_file = '/content/L1.txt'
sentences = []
with open(corpus_file, 'r', encoding="utf-8-sig") as f:
    for line in f:
        sentences.append(line.split())       
print('Num sentences:', len(sentences))

# %%
#Insertion Cluster
f = open("data-1.txt", "x")
f = open("data-1.txt", "a")
from random import random, choice

InsertDict = {'ক': ['ল'],
              'খ': ['গ'],
              'গ' : ['ফ','হ'], 
              'ঘ' : ['জ'],
              'ঙ' : ['ম'],
              'চ' : ['জ'],
              'ছ' : ['জ'],
              'জ' : ['ক'],
              'ঝ' : ['গ'],
              'ট' : ['র'],
              'ঠ' : ['জ'],
              'ড' : ['স'],
              'ঢ' : ['জ'],
              'ণ' : ['ম'],
              'ত' : ['র'],
              'থ' : ['জ'],
              'দ' : ['স'],
              'ধ' : ['জ'],
              'ন' : ['ম'],
              'প' : [''],
              'ফ' : ['দ'],
              'ব' : ['ন'],
              'ম' : [''],
              'য' : ['ক'],
              'র' : ['ে'],
              'ল' : [''],
              'শ' : ['জ'],
              'ষ' : ['জ'],
              'স' : ['া'],
              'হ' : ['জ'],
              'য়' : ['ু'],
              'ড়' : ['ে'],
              'ঢ়' : ['ে'],
              'ৎ' : ['র'],
              'ং' : ['ম'],
              'ঃ' : ['জ'],
              'অ' : ['প'],
              'আ' : [''],
              'ই' : ['অ'],
              'ঈ' : ['অ'],
              'উ' : ['ি'],
              'ঊ' : ['ি'],
              'ঋ' : ['ো'],
              'এ' : ['ও'],
              'ঐ' : ['ু'],
              'ও' : ['প'],
              'ঔ' : ['য়'],
             }

character = ['অ','আ','ই','ঈ','উ','ঊ','এ','ঐ','ও','ঔ','ঋ','ঃ','ং','ৎ'
             'ক','খ','গ','ঘ','ঙ','চ', 'ছ','য','জ', 'ঝ','ট','ঠ','ড','র','ড়','ঢ়',
             'ণ','ত','থ','দ','ধ','ন','প','ফ','ব','ভ','ম','স','শ','ষ','য়','হ']
def lenth(words):
  l=0
  for i in words:
    if i in character:
      l += 1
  return l

def insert(word2):
  c = choice(word2)
  if c in InsertDict:
    position = word2.index(c)
    c2 = choice(InsertDict[c])
    return c2,position+1
  else:
    return insert(word2)

def insertChar(mystring, position, chartoinsert ):
    longi = len(mystring)
    mystring   =  mystring[:position] + chartoinsert + mystring[position:] 
    return mystring

for line in sentences:
  for word in line:
    print(word,end=',')
    if lenth(word) > 3:
      element,index = insert(word)
      word = insertChar(word, index, element)
      print(word)
      f.write(word)
    else:
      print(word)
      f.write(word)
  f.write("\n")
f.close()
